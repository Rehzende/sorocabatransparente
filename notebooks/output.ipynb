# %% [markdown]
# ## Extração dos ID's e URL das fotos dos Vereadores

# %%
# %pip install requests 
# %pip install bs4
# %pip install unidecode
# Out:
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.9.16/x64/lib/python3.9/site-packages (from requests) (3.4)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 9.8 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 12.3 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: charset-normalizer, urllib3, certifi, requests
# Successfully installed certifi-2022.12.7 charset-normalizer-3.0.1 requests-2.28.2 urllib3-1.26.14
# Note: you may need to restart the kernel to use updated packages.
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# done
# Requirement already satisfied: beautifulsoup4 in /opt/hostedtoolcache/Python/3.9.16/x64/lib/python3.9/site-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/hostedtoolcache/Python/3.9.16/x64/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.4)
# Installing collected packages: bs4
#   DEPRECATION: bs4 is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
# done
# Successfully installed bs4-0.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
from unidecode import unidecode


vereadores = []

for vereador_id in range(1, 200):
    url = f'http://www.camarasorocaba.sp.gov.br/vereador.html?id={vereador_id}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    try:
        nome_vereador = soup.find('div', {'class': 'page-header'}).find('h1').text
        print(f'Vereador {vereador_id}: {nome_vereador}')
        vereador_dict = {
            "nome": nome_vereador,
            "id": vereador_id,
            "imagem_url": f"http://syslegis.camarasorocaba.sp.gov.br:8383/syslegis/vereador/getConteudo/{vereador_id}"
        }
        vereadores.append(vereador_dict)
    except AttributeError:
        print(f'Erro ao obter o nome do vereador {vereador_id}')

with open('../dados/vereadores/vereadores.json', 'w', encoding='utf-8') as f:
    json.dump(vereadores, f, ensure_ascii=False, indent=4)
# Out:
# Erro ao obter o nome do vereador 1
# Vereador 2: Anselmo Rolim Neto
# Vereador 3: Benedito de Jesus Oleriano
# Vereador 4: Carlos Cezar da Silva
# Vereador 5: Emílio Souza de Oliveira
# Vereador 6: Francisco França da Silva
# Vereador 7: Francisco Moko Yabiku
# Vereador 8: Gervino Cláudio Gonçalves
# Vereador 9: Irineu Donizeti de Toledo
# Vereador 10: Izídio de Brito Correia
# Vereador 11: João Donizeti Silvestre
# Vereador 12: José Antonio Caldini Crespo
# Vereador 13: José Francisco Martinez
# Vereador 14: José Geraldo Reis Viana
# Vereador 15: Luis Santos Pereira Filho
# Vereador 16: Mário Marte Marinho Júnior
# Vereador 17: Paulo Francisco Mendes
# Vereador 18: Rozendo de Oliveira
# Vereador 19: Antonio Carlos Silvano
# Vereador 20: Claudemir José Justi
# Vereador 21: Vitor Francisco da Silva
# Vereador 22: Rodrigo Maganhato
# Vereador 23: Fernando Alves Lisboa Dini
# Vereador 24: Valdecir Moreira da Silva
# Vereador 25: José Apolo da Silva
# Vereador 26: Maurício Rodrigues da Silva
# Vereador 27: Jessé Loures de Moraes
# Vereador 28: Francisco Carlos Silveira Leite
# Vereador 29: Saulo da Silva
# Vereador 30: Waldomiro Raimundo de Freitas
# Vereador 31: Neusa Maldonado Silveira
# Vereador 32: Helio Aparecido de Godoy
# Vereador 33: Wanderley Diogo de Melo
# Erro ao obter o nome do vereador 34
# Erro ao obter o nome do vereador 35
# Erro ao obter o nome do vereador 36
# Erro ao obter o nome do vereador 37
# Erro ao obter o nome do vereador 122
# Erro ao obter o nome do vereador 123
# Erro ao obter o nome do vereador 124
# Erro ao obter o nome do vereador 125
# Erro ao obter o nome do vereador 126
# Erro ao obter o nome do vereador 127
# Erro ao obter o nome do vereador 128
# Erro ao obter o nome do vereador 129
# Erro ao obter o nome do vereador 130
# Erro ao obter o nome do vereador 131
# Erro ao obter o nome do vereador 132
# Vereador 133: José Roberto Medina
# Erro ao obter o nome do vereador 134
# Erro ao obter o nome do vereador 135
# Erro ao obter o nome do vereador 136
# Vereador 137: Rodrigo Piveta Berno
# Vereador 138: Antonio Cicero da Silva
# Erro ao obter o nome do vereador 139
# Erro ao obter o nome do vereador 140
# Erro ao obter o nome do vereador 141
# Erro ao obter o nome do vereador 142
# Vereador 143: Anselmo Augusto Branco Bastos
# Vereador 144: Ítalo Gabriel Moreira
# Vereador 145: Cícero João da Silva
# Vereador 146: José Vinícius Campos Aith
# Vereador 147: Cristiano Anunciação dos Passos
# Vereador 148: Dylan Roberto Viana Dantas
# Vereador 149: Fabio Simoa Mendes do Carmo Leite
# Vereador 150: Salatiel dos Santos Hergesel
# Erro ao obter o nome do vereador 151
# Erro ao obter o nome do vereador 152
# Erro ao obter o nome do vereador 153
# Erro ao obter o nome do vereador 154
# Erro ao obter o nome do vereador 155
# Erro ao obter o nome do vereador 156
# Erro ao obter o nome do vereador 157
# Erro ao obter o nome do vereador 158
# Erro ao obter o nome do vereador 159
# Erro ao obter o nome do vereador 160
# Erro ao obter o nome do vereador 161
# Erro ao obter o nome do vereador 162
# Erro ao obter o nome do vereador 163
# Erro ao obter o nome do vereador 164
# Erro ao obter o nome do vereador 165
# Erro ao obter o nome do vereador 166
# Erro ao obter o nome do vereador 167
# Erro ao obter o nome do vereador 168
# Erro ao obter o nome do vereador 169
# Erro ao obter o nome do vereador 170
# Erro ao obter o nome do vereador 171
# Erro ao obter o nome do vereador 172
# Erro ao obter o nome do vereador 173
# Erro ao obter o nome do vereador 174
# Erro ao obter o nome do vereador 175
# Erro ao obter o nome do vereador 176
# Erro ao obter o nome do vereador 177
# Erro ao obter o nome do vereador 178
# Erro ao obter o nome do vereador 179
# Erro ao obter o nome do vereador 180
# Erro ao obter o nome do vereador 181
# Erro ao obter o nome do vereador 182
# Erro ao obter o nome do vereador 183
# Erro ao obter o nome do vereador 184
# Erro ao obter o nome do vereador 185
# Erro ao obter o nome do vereador 186
# Erro ao obter o nome do vereador 187
# Erro ao obter o nome do vereador 188
# Erro ao obter o nome do vereador 189
# Erro ao obter o nome do vereador 190
# Erro ao obter o nome do vereador 191
# Erro ao obter o nome do vereador 192
# Erro ao obter o nome do vereador 193
# Erro ao obter o nome do vereador 194
# Erro ao obter o nome do vereador 195
# Erro ao obter o nome do vereador 196
# Erro ao obter o nome do vereador 197
# Erro ao obter o nome do vereador 198
# Erro ao obter o nome do vereador 199

# %% [markdown]
# ## Extração dos ID's do Ano de cada pagina de relatorio.

# %%
import json, requests
from bs4 import BeautifulSoup
from pathlib import Path


LINKS_FILE_PATH = '../dados/relatorios/links.json'

def extract_year_data(existing_data):
    print('Carregando dados')
    url = 'http://www.camarasorocaba.sp.gov.br/arquivos_publicos.html?id=5e3f0dc905d7040f28b44e0e'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    table = soup.find('table', {'class': 'table table-striped'})
    for year in table.find_all('a'):
        year_str = year.contents[2].strip()

        # Verificar se já existe um dicionário para este ano
        year_exists = False
        if existing_data:
            for data in existing_data:
                if data['year'] == year_str:
                    year_exists = True
                    break

        if not year_exists:
            existing_data.append({'url_id': year.get('href'), 'year': year_str, 'processed': False, 'extracted': False, 'months': []})
        else:
            print(f"Já existe um dicionário para o ano {year_str}. Ignorando.")


try:
    links_file_path = Path(LINKS_FILE_PATH)
    with links_file_path.open("r+", encoding="utf8") as f:
        data = json.load(f)

    print('extraindo')
    extract_year_data(data)

    with links_file_path.open("w", encoding="utf8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
except Exception as e:
    print(f"Erro ao ler arquivo JSON: {str(e)}")
    data = []
# Out:
# extraindo
# Carregando dados
# Já existe um dicionário para o ano 2022. Ignorando.
# Já existe um dicionário para o ano 2021. Ignorando.
# Já existe um dicionário para o ano 2020. Ignorando.
# Já existe um dicionário para o ano 2019. Ignorando.
# Já existe um dicionário para o ano 2018. Ignorando.
# Já existe um dicionário para o ano 2017. Ignorando.
# Já existe um dicionário para o ano 2016. Ignorando.
# Já existe um dicionário para o ano 2015. Ignorando.
# Já existe um dicionário para o ano 2014. Ignorando.
# Já existe um dicionário para o ano 2013. Ignorando.
# Já existe um dicionário para o ano 2012. Ignorando.
# Já existe um dicionário para o ano 2011. Ignorando.
# Já existe um dicionário para o ano 2010. Ignorando.
# Já existe um dicionário para o ano 2009. Ignorando.
# Já existe um dicionário para o ano 2008. Ignorando.
# Já existe um dicionário para o ano 2007. Ignorando.
# Já existe um dicionário para o ano 2006. Ignorando.
# Já existe um dicionário para o ano 2005. Ignorando.

# %% [markdown]
# ## Extração dos ID's do relatório de cada mês do ano.

# %%
import json
from pathlib import Path
import requests
from bs4 import BeautifulSoup

BASE_URL = 'http://www.camarasorocaba.sp.gov.br/arquivos_publicos.html'
LINKS_FILE_PATH = '../dados/relatorios/links.json'

def scrape_monthly_reports(year_data, base_url):
    if year_data["extracted"] == False:
        response = requests.get(f"{base_url}{year_data['url_id']}")
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', {'class': 'table table-striped'})
        for link in table.find_all('a'):
            url_id = link.get('href')
            month = link.contents[2].strip()
            exists_month = False
            for m in year_data['months']:
                if m["month"] == month:
                    exists_month = True
                    break

            if not exists_month:

                new_month = {
                    "url_id":  url_id,
                    "month": month,
                    "processed": False,
                    "extracted": False,
                    "report_path": "",
                    "file_extension": ""
                }
                year_data['months'].append(new_month)

try:
    links_file_path = Path(LINKS_FILE_PATH)
    with links_file_path.open("r+", encoding="utf8") as f:
        dados = json.load(f)
except Exception as e:
    print(f"Erro ao ler arquivo JSON: {str(e)}")
    dados = []

for year_data in dados:

    scrape_monthly_reports(year_data, BASE_URL)

    with links_file_path.open("w", encoding="utf8") as f:
        json.dump(dados, f, ensure_ascii=False, indent=4)
